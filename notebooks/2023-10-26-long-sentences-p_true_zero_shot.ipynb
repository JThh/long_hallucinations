# %% [markdown]
# # p_true zero-shot
#
# * What happens to p_true with no prompt at all (zero-shot) / and with slightly improved instruction for zero-shot (the 'a' 'b' is a bit misleading w/o examples)
#
#
# * the zero-shot setting is bad
#
# * the slightly improved prompt helps performance

# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir('../..')
import pickle
import yaml
import json

from matplotlib import pyplot as plt
import pandas as pd
import numpy as np


from copy import deepcopy
import seaborn as sns

import wandb
api = wandb.Api()
api.entity = 'goatml'

# %%
# export to eval file
def get_vals(x):
    return x['mean'], x['mean']-x['bootstrap']['std_err'], x['mean']+x['bootstrap']['std_err']

def get_vals2(x):
    return x['means'], x['low'], x['high']


def get_perfs(metrics):
    data = []
    for method in metrics['performance']:
        mean, low, high = get_vals(metrics['performance'][method])
        data.append([method, mean, low, high])
    
    df = pd.DataFrame(data, columns=['method', 'means', 'low', 'high'])
    return df.set_index('method')

def plot_bar(df, color='C0', ax=None):
    if ax is None:
        fig, ax = plt.subplots()

    df.plot.bar(y='means', yerr=[df.means - df.low, df.high - df.means], color=color, ax=ax)

def get_uncertainty_df(metrics):
    data = []
    for method in metrics['uncertainty']:
        for metric in metrics['uncertainty'][method]:
            mean, low, high = get_vals(metrics['uncertainty'][method][metric])
            data.append([method, metric, mean, low, high])
    
    df = pd.DataFrame(data, columns=['method', 'metric', 'means', 'low', 'high'])
    
    df = df.set_index('method')

    def get_base_method(x):
        if 'p_false' in x:
            return 'p_false'
        elif 'p_ik' in x:
            return 'p_ik'
        elif 'regular_entropy' in x:
            return 'regular_entropy'
        elif 'cluster_assignment' in x:
            return x
        elif 'semantic_entropy' in x:
            return 'semantic_entropy'
        else:
            raise
    df['base_method'] = df.index.map(get_base_method)
    return df

def plot_bar_uncertainty(pdf, metric, remove='_UNANSWERABLE', ax=None):
    if ax is None:
        fig, ax = plt.subplots()

    tmp = pdf
    # filter out unanswerable
    if remove is not None:
        tmp = tmp[tmp.index.map(lambda x: remove not in x)]
    tmp = tmp.reset_index()
    tmp = tmp.set_index('metric').loc[metric]
    tmp = tmp.set_index('method')
    tmp = tmp.sort_values('base_method')

    b2c = {m:f'C{i}' for i, m in enumerate(tmp.base_method.unique())}
    basemethod2color = lambda x: b2c[x]

    plot_bar(tmp, color=tmp.base_method.map(basemethod2color), ax=ax)
    ax.grid(axis='y', zorder=-10, alpha=0.3)

# %%
def restore_file(wandb_id, filenames=['wandb-summary.json', 'config.yaml']):
    files_dir = 'notebooks/restored_files'    
    os.system(f'mkdir -p {files_dir}')

    run = api.run(f'goatml/semantic_uncertainty/{wandb_id}')
    # run = api.run(f'goatml/uncertainty/{wandb_id}')
    out = []

    for filename in filenames:
        
        path = f'{files_dir}/{filename}'
        os.system(f'rm -rf {path}')
        run.file(filename).download(root=files_dir, replace=True, exist_ok=False)
    
        if filename.endswith('.pkl'):
            with open(path, 'rb') as f:
                out.append(pickle.load(f))
        elif filename.endswith('.yaml'):
            with open(path, 'r') as f:
                out.append(yaml.safe_load(f))
        elif filename.endswith('.json'):
            with open(path, 'r') as f:
                out.append(json.load(f))
        else:
            raise

    return out

# %%
# The new runs are doing strict entailment _and_ condition on question,
runs = {
#     'sy2g4uyv': '70b-trivia-qa',
#     'ispvyuub': '70b-trivia-no-context',
#     # NOTE: 70-bSQUAD RUNS ONLY HAVE 5 GENERATIONS !!
#     '3dh1kja3': '70b-squad', # n2bhdjad
#     'jky7j51k': '70b-squad-AO', # answerable only 'ttd2db7b''
#     'zodwzypf': '70b-squad-AO-NC', # answerable only, no-context 'ttd2db7b''
# # 
#     '4qrza8sl': '7b-trivia-qa',
#     'gk0phirh': '7b-trivia-no-context',
#     '7nlpwfzq': '7b-squad', # n2bhdjad
#     'bd90qu2n': '7b-squad-AO', # answerable only 'ttd2db7b''
#     'cizk4p88': '7b-squad-AO-NC', # answerable only, no-context 'ttd2db7b''
# 
    'au7s3uxg': '70b-trivia_qa',
    '4os83psm': '70b-trivia_qa-0shot',
    '5najowtk': '70b-trivia_qa-0shot-hint',
    'e5ptgcwr': '70b-bioasq',
    'flpks3no': '70b-bioasq-0shot-hint',  # hint is improved prompt for p_true
    'ooslwgb9': '70b-squad',
    'bv0uum96': '70b-squad-0shot',
    'vfce0o8f': '70b-squad-0shot-hint',
    # 'zs85ypn3': '70b-record',
}

all_configs, all_results = {}, {}

for wandb_id in runs:
    all_results[wandb_id], all_configs[wandb_id] = restore_file(wandb_id)

# %%
get_cfg = lambda dictionary: {k: v['value'] for k, v in dictionary.items() if isinstance(v, dict) and k != '_wandb'}
def get_diff(xk, yk):

    x, y = all_configs[xk], all_configs[yk]
    print(20*' ' + f'{runs[xk]:<20} {runs[yk]}')
    diffs = set(get_cfg(x).items()) ^ set(get_cfg(y).items())
    for k, _ in diffs:
        print(f'{k:<20} {get_vals(x).get(k, "missing"):<20} {get_vals(y).get(k, "missing")}')
    print(80 * '-')


get_diff('au7s3uxg', '4os83psm')
get_diff('au7s3uxg', '5najowtk')
get_diff('e5ptgcwr', 'flpks3no')
get_diff('ooslwgb9', 'bv0uum96')
get_diff('ooslwgb9', 'vfce0o8f')
# Out:
#                     70b-trivia_qa        70b-trivia_qa-0shot
# ood_train_dataset    missing              None
# entailment_model     missing              deberta
# p_true_num_fewshot   5                    0
# p_true_hint          missing              False
# p_true_num_fewshot   5                    0
# --------------------------------------------------------------------------------
#                     70b-trivia_qa        70b-trivia_qa-0shot-hint
# ood_train_dataset    missing              None
# p_true_hint          missing              True
# entailment_model     missing              deberta
# p_true_num_fewshot   5                    0
# p_true_num_fewshot   5                    0
# --------------------------------------------------------------------------------
#                     70b-bioasq           70b-bioasq-0shot-hint
# ood_train_dataset    missing              None
# p_true_hint          missing              True
# entailment_model     missing              deberta
# p_true_num_fewshot   5                    0
# p_true_num_fewshot   5                    0
# --------------------------------------------------------------------------------
#                     70b-squad            70b-squad-0shot
# ood_train_dataset    missing              None
# entailment_model     missing              deberta
# p_true_num_fewshot   5                    0
# p_true_hint          missing              False
# p_true_num_fewshot   5                    0
# --------------------------------------------------------------------------------
#                     70b-squad            70b-squad-0shot-hint
# ood_train_dataset    missing              None
# p_true_hint          missing              True
# entailment_model     missing              deberta
# p_true_num_fewshot   5                    0
# p_true_num_fewshot   5                    0
# --------------------------------------------------------------------------------

# %% [markdown]
# Can we improve accuracy by instead voting the answer from the (high-temperature) clusters?

# %%
for wandb_id, run_name in runs.items():
    config = all_configs[wandb_id]
    results = all_results[wandb_id]

    df = get_perfs(results)
    plot_bar(df)
    plt.gca().set_title(run_name)
    plt.gca().grid()
    plt.gca().set_ylim(0, 1)

# %%
perfdf = {}
for wandb_id, run_name in runs.items():
    results = all_results[wandb_id]    
    perfdf[wandb_id] = get_perfs(results)

runids = list(perfdf.keys())
tmp = pd.DataFrame(perfdf[runids[0]])
tmp['run'] = runs[runids[0]]

for runid in runids[1:]:
    tmp2 = pd.DataFrame(perfdf[runid])
    tmp2['run'] = runs[runid]
    
    tmp = pd.concat([tmp, tmp2])

perfdf = tmp.reset_index()

# %%
plot_bar(perfdf.set_index('method').loc['accuracy'].set_index('run'))
plt.gca().set_ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
tmp = perfdf.set_index('method').loc['accuracy']
tmp['model'] = tmp.run.map(lambda x: '-'.join(x.split('-')[:1]))
tmp['dataset'] = tmp.run.map(lambda x: '-'.join(x.split('-')[1:]))
tmp.pivot(columns='model', index='dataset', values='means')
# Out:
# model                   70b
# dataset
# bioasq                0.565
# bioasq-0shot-hint     0.575
# squad                 0.350
# squad-0shot           0.375
# squad-0shot-hint      0.355
# trivia_qa             0.850
# trivia_qa-0shot       0.905
# trivia_qa-0shot-hint  0.850

# %% [markdown]
# * 7b largely performs very similar to 70b, usually a little worse (5-10%)
# * Only big difference is for trivia-qa, where removing context leads to ~20 percent accuracy hit from ~85 to ~65 (this is not necessarily bad for us though)

# %%
metric_names = [
    'AUROC',
    'area_under_thresholded_accuracy',
    'mean_uncertainty',
    'accuracy_at_0.8_answer_fraction',
    'accuracy_at_0.9_answer_fraction',
    'accuracy_at_0.95_answer_fraction'
]

pdfs = {}
for wandb_id in runs:
    results = all_results[wandb_id]
    pdfs[wandb_id] = get_uncertainty_df(results)

# %%
fig, axes_2d = plt.subplots(len(metric_names), len(runs), sharex=True, figsize=(15, 15), dpi=100)
# fig.suptitle(config['dataset']['value'] + ' '+ plt.gca().get_title())
for k, (name, axes) in enumerate(zip(list(metric_names), axes_2d)):

    for i, (ax, wandb_id) in enumerate(zip(axes, runs)):
        plot_bar_uncertainty(pdfs[wandb_id], name, ax=ax)

        if i == 0:
            ax.set_ylabel(name, fontsize=8, rotation=0, ha='right')

        if k == 0:
            ax.set_title(runs[wandb_id])


plt.tight_layout()
plt.subplots_adjust(wspace=0.1, hspace=0.1)

# %%
runids = list(pdfs.keys())

tmp = pd.DataFrame(pdfs[runids[0]])
tmp['run'] = runs[runids[0]]

for runid in runids[1:]:
    tmp2 = pd.DataFrame(pdfs[runid])
    tmp2['run'] = runs[runid]
    
    tmp = pd.concat([tmp, tmp2])

all_runs = tmp.reset_index()

# %%
df2 = deepcopy(all_runs)
df2 = df2[all_runs.method == 'cluster_assignment_entropy']
df2 = df2.sort_values(['run', 'metric'])

fig, ax = plt.subplots(1, 1, figsize=(10, 8), sharey=True, dpi=100)

g = sns.barplot(
    x="metric",       # x variable name
    y="means",       # y variable name
    hue="run",  # group variable name
    data=df2,     # dataframe to plot
    ax=ax,
)

# https://stackoverflow.com/questions/72352491/how-to-plot-errorbars-on-seaborn-barplot
x_coords = [p.get_x() + 0.5 * p.get_width() for p in ax.patches]
y_coords = [p.get_height() for p in ax.patches]

for kind in ['low', 'high']:
    tmp = df2[kind].values
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    ax.scatter(x_coords[:-len(df2.run.unique())], tmp, c='red', marker='x')
ax.grid(zorder=-100, alpha=0.2)
# ax.set_ylim(0.3, 1)
plt.tight_layout()
# Out:
# /tmp/ipykernel_369817/1764243749.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_369817/1764243749.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
df2 = deepcopy(all_runs)
df2 = df2[all_runs.method == 'semantic_entropy_sum_cmean']
df2 = df2[all_runs.metric != 'mean_uncertainty']

df2 = df2.sort_values(['run', 'metric'])

fig, ax = plt.subplots(1, 1, figsize=(10, 8), sharey=True, dpi=100)

g = sns.barplot(
    x="metric",       # x variable name
    y="means",       # y variable name
    hue="run",  # group variable name
    data=df2,     # dataframe to plot
    ax=ax,
)

# https://stackoverflow.com/questions/72352491/how-to-plot-errorbars-on-seaborn-barplot
x_coords = [p.get_x() + 0.5 * p.get_width() for p in ax.patches]
y_coords = [p.get_height() for p in ax.patches]

for kind in ['low', 'high']:
    tmp = df2[kind].values
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    ax.scatter(x_coords[:-len(df2.run.unique())], tmp, c='red', marker='x')
ax.grid(zorder=-100, alpha=0.2)
# ax.set_ylim(0.3, 1)
plt.tight_layout()
# Out:
# /tmp/ipykernel_369817/1448009336.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[all_runs.metric != 'mean_uncertainty']
# /tmp/ipykernel_369817/1448009336.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_369817/1448009336.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
df2 = deepcopy(all_runs)
df2 = df2[df2.metric == 'AUROC']
main_methods = ['cluster_assignment_entropy', 'regular_entropy', 'semantic_entropy', 'p_ik', 'p_false', 'semantic_entropy_sum-normalized_max_from_semantic_entropy_sum-normalized', 'semantic_entropy_sum-normalized-rao_max_from_semantic_entropy_sum-normalized-rao']

df2 = df2[df2.method.map(lambda x: x in main_methods)]
df2 = df2.sort_values(['method', 'run'])

fig, ax = plt.subplots(1, 1, figsize=(15, 8), sharey=True, dpi=100)

g = sns.barplot(
    x="run",       # x variable name
    y="means",       # y variable name
    hue="method",  # group variable name
    data=df2,     # dataframe to plot
    ax=ax,
)

# https://stackoverflow.com/questions/72352491/how-to-plot-errorbars-on-seaborn-barplot
x_coords = [p.get_x() + 0.5 * p.get_width() for p in ax.patches]
y_coords = [p.get_height() for p in ax.patches]

for kind in ['low', 'high']:
    tmp = df2[kind].values
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    ax.scatter(x_coords[:-len(df2.method.unique())], tmp, c='red', marker='x')
ax.grid(zorder=-100, alpha=0.2)
# ax.set_ylim(0.3, 1)
plt.tight_layout()
# Out:
# /tmp/ipykernel_369817/3628602304.py:24: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_369817/3628602304.py:24: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
tmp = all_runs.set_index('metric').loc['AUROC']
tmp = tmp[tmp.method.map(lambda x: 'UNANSWERABLE' not in x)]

# %%
# for each run (and for each model) I would like to see the best methods

# %%
# semantic_entropy_sum-normalized-rao_max_from_semantic_entropy_sum-normalized-rao --> this was the best method for short generations as well!

# %%
tmp.groupby('method').mean('means').sort_values('means', ascending=False)
# Out:
#                                                        means       low  \
# method
# p_false                                             0.792125  0.752890
# semantic_entropy_sum-normalized-rao                 0.739844  0.695321
# semantic_entropy_sum-normalized-rao_max_from_se...  0.739195  0.693099
# cluster_assignment_entropy                          0.737583  0.696432
# semantic_entropy_max_from_semantic_entropy          0.736255  0.692540
# semantic_entropy                                    0.735083  0.692887
# semantic_entropy_sum-normalized_max_from_semant...  0.728082  0.682550
# semantic_entropy_sum-normalized                     0.724898  0.680779
# semantic_entropy_sum_sum-normalized-rao             0.699014  0.653737
# semantic_entropy_sum_sum-normalized-rao_max_fro...  0.694053  0.647165
# semantic_entropy_sum                                0.685780  0.642421
# semantic_entropy_sum_sum-normalized                 0.683777  0.639744
# semantic_entropy_sum_max_from_semantic_entropy_sum  0.682842  0.638003
# semantic_entropy_sum_sum-normalized_max_from_se...  0.673434  0.627582
# semantic_entropy_sum_cmean                          0.665655  0.622537
# semantic_entropy_sum_cmean_max_from_semantic_en...  0.659335  0.615062
# regular_entropy_sum                                 0.642556  0.597354
# semantic_entropy_cmean                              0.639224  0.592729
# regular_entropy                                     0.638298  0.590763
# semantic_entropy_cmean_max_from_semantic_entrop...  0.629181  0.581453
# p_ik                                                0.593075  0.545097
#
#                                                         high
# method
# p_false                                             0.831361
# semantic_entropy_sum-normalized-rao                 0.784366
# semantic_entropy_sum-normalized-rao_max_from_se...  0.785290
# cluster_assignment_entropy                          0.778733
# semantic_entropy_max_from_semantic_entropy          0.779970
# semantic_entropy                                    0.777280
# semantic_entropy_sum-normalized_max_from_semant...  0.773614
# semantic_entropy_sum-normalized                     0.769016
# semantic_entropy_sum_sum-normalized-rao             0.744290
# semantic_entropy_sum_sum-normalized-rao_max_fro...  0.740941
# semantic_entropy_sum                                0.729138
# semantic_entropy_sum_sum-normalized                 0.727809
# semantic_entropy_sum_max_from_semantic_entropy_sum  0.727681
# semantic_entropy_sum_sum-normalized_max_from_se...  0.719286
# semantic_entropy_sum_cmean                          0.708774
# semantic_entropy_sum_cmean_max_from_semantic_en...  0.703608
# regular_entropy_sum                                 0.687758
# semantic_entropy_cmean                              0.685720
# regular_entropy                                     0.685832
# semantic_entropy_cmean_max_from_semantic_entrop...  0.676909
# p_ik                                                0.641054

# %%
tmp[tmp.run.map(lambda x: '70b' in x)].groupby('method').mean('means').sort_values('means', ascending=False)
# Out:
#                                                        means       low  \
# method
# semantic_entropy_sum-normalized-rao_max_from_se...  0.716949  0.675224
# p_false                                             0.707174  0.666164
# semantic_entropy_sum-normalized_max_from_semant...  0.704048  0.663010
# semantic_entropy_max_from_semantic_entropy          0.703945  0.661362
# semantic_entropy_sum-normalized-rao                 0.699660  0.659345
# cluster_assignment_entropy                          0.687604  0.646744
# semantic_entropy_sum-normalized                     0.686985  0.646087
# semantic_entropy                                    0.677258  0.633911
# p_ik                                                0.673123  0.630563
# semantic_entropy_sum_max_from_semantic_entropy_sum  0.672065  0.629292
# semantic_entropy_sum_sum-normalized-rao_max_fro...  0.659293  0.616060
# semantic_entropy_sum_cmean_max_from_semantic_en...  0.656422  0.614031
# semantic_entropy_sum_sum-normalized_max_from_se...  0.653234  0.610418
# semantic_entropy_sum_sum-normalized-rao             0.652827  0.609050
# semantic_entropy_sum                                0.642156  0.597841
# semantic_entropy_sum_sum-normalized                 0.640948  0.598915
# semantic_entropy_cmean_max_from_semantic_entrop...  0.628659  0.584677
# semantic_entropy_sum_cmean                          0.626828  0.583144
# semantic_entropy_cmean                              0.605861  0.561435
# regular_entropy_sum                                 0.603111  0.558810
# regular_entropy                                     0.599082  0.553658
#
#                                                         high
# method
# semantic_entropy_sum-normalized-rao_max_from_se...  0.758674
# p_false                                             0.748185
# semantic_entropy_sum-normalized_max_from_semant...  0.745087
# semantic_entropy_max_from_semantic_entropy          0.746527
# semantic_entropy_sum-normalized-rao                 0.739976
# cluster_assignment_entropy                          0.728464
# semantic_entropy_sum-normalized                     0.727883
# semantic_entropy                                    0.720605
# p_ik                                                0.715683
# semantic_entropy_sum_max_from_semantic_entropy_sum  0.714838
# semantic_entropy_sum_sum-normalized-rao_max_fro...  0.702527
# semantic_entropy_sum_cmean_max_from_semantic_en...  0.698813
# semantic_entropy_sum_sum-normalized_max_from_se...  0.696050
# semantic_entropy_sum_sum-normalized-rao             0.696605
# semantic_entropy_sum                                0.686471
# semantic_entropy_sum_sum-normalized                 0.682981
# semantic_entropy_cmean_max_from_semantic_entrop...  0.672641
# semantic_entropy_sum_cmean                          0.670511
# semantic_entropy_cmean                              0.650287
# regular_entropy_sum                                 0.647411
# regular_entropy                                     0.644506

# %%
tmp[tmp.run.map(lambda x: '7b' in x)].groupby('method').mean('means').sort_values('means', ascending=False)

# %%
tmp.set_index('method').loc[main_methods].reset_index().groupby('method').mean('means').sort_values('means', ascending=False)

# %%
tmp[tmp.run.map(lambda x: '7b' in x)].set_index('method').loc[main_methods].reset_index().groupby('method').mean('means').sort_values('means', ascending=False)
