# %% [markdown]
# ## Alignment of Latent Probe Uncertainty with Semantic Entropy
#
# We intervene contexts of questions and study change of semantic uncertainty.
#
# We take the examples from llama-2-7b on trivia-qa.

# %%
# Select records that exhibit high semantic uncertainty
